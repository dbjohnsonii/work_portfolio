# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import sys
print (sys.version)
# Out:
# <style>.container { width:95% !important; }</style>
# 2.7.12 |Anaconda 4.2.0 (64-bit)| (default, Jun 29 2016, 11:07:13) [MSC v.1500 64 bit (AMD64)]

# %%
import pandas as pd

# %%
vi_import='d:\\djohnson\\Desktop\\misuse\\2018\\apr\\invoice_files\\mc_eu_integ.csv'
mu_import='d:\\djohnson\\Desktop\\misuse\\2018\\apr\\invoice_files\\mc_row_integ.csv'
mu_e_import='d:\\djohnson\\Desktop\\misuse\\2018\\apr\\invoice_files\\vi_integ.csv'

# %%
vi=pd.read_csv(vi_import,sep=';')
mr=pd.read_csv(mu_import,sep=';')
me=pd.read_csv(mu_e_import,sep=';')

# %%
m=pd.concat([vi,mr,me])

# %%
m['InvoiceDate']=201805

# %%
m=m.groupby(['Contract_ID','ProductCode','InvoiceDate','Approved'],as_index=False)[['Value']].sum()

# %%
m['Value']=m['Value'].round(2)

# %%
m=m[['Contract_ID','ProductCode','Value','InvoiceDate','Approved']]

# %%
m['Contract_ID']=m['Contract_ID'].astype(int).astype(str)

# %%
m['Contract_ID'][(m['Contract_ID'].str.len()==3)]="0"+m['Contract_ID']
# Out:
# C:\Users\djohnson\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
m=m.set_index('Contract_ID',inplace=False,append=False)

# %%
m.head(50)
# Out:
#              ProductCode    Value  InvoiceDate Approved
# Contract_ID
# 0278              420129     0.33       201805    False
# 0297              420129     6.95       201805    False
# 0759              420129     1.58       201805    False
# 0760              420129     3.88       201805    False
# 0764              420129     0.09       201805    False
# 0766              420129     0.39       201805    False
# 0787              420129     0.34       201805    False
# 0946              420129     0.07       201805    False
# 0988              420129    32.66       201805    False
# 0991              420129   110.03       201805    False
# 0992              420129     0.52       201805    False
# 1074              420129    19.44       201805    False
# 1075              420129    19.66       201805    False
# 1078              420129    47.04       201805    False
# 1085              420129     2.63       201805    False
# 1086              420129    62.19       201805    False
# 1098              420129    20.32       201805    False
# 1167              420129     0.14       201805    False
# 1188              420129     6.27       201805    False
# 1196              420129     0.18       201805    False
# 1431              420129     0.03       201805    False
# 1666              420129     1.63       201805    False
# 1834              420129     6.39       201805    False
# 1837              420129     0.06       201805    False
# 1860              420129    20.66       201805    False
# 1968              420129     1.87       201805    False
# 1979              420129    28.20       201805    False
# 1983              420129     0.12       201805    False
# 2046              420129     0.27       201805    False
# 2060              420129     1.41       201805    False
# 2288              420129     0.07       201805    False
# 2408              420129     1.18       201805    False
# 2415              420129     1.66       201805    False
# 2520              420129     4.40       201805    False
# 2876              420129     2.32       201805    False
# 2993              420129     7.02       201805    False
# 3199              420129     0.27       201805    False
# 3287              420129     0.08       201805    False
# 3344              420129    38.12       201805    False
# 3382              420129   173.98       201805    False
# 3435              420129    10.58       201805    False
# 3436              420129  3935.92       201805    False
# 3524              420129     0.09       201805    False
# 3525              420129     0.12       201805    False
# 3623              420129     0.74       201805    False
# 3682              420129    41.25       201805    False
# 3684              420129    13.85       201805    False
# 3780              420129    18.81       201805    False
# 3834              420129    23.78       201805    False
# 3836              420129     0.03       201805    False

# %%
m.to_csv('d:\\djohnson\\Desktop\\misuse\\BI000001_05292018.csv',sep=';')
